# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\lbicalho\\stuff\\varredura\\arquivos.csv")
df
# Out:
#                                                   caminho          dono  \
# 0                              C:\Users\lbicalho\.condarc  HFA\lbicalho
# 1                            C:\Users\lbicalho\.gitconfig  HFA\lbicalho
# 2                              C:\Users\lbicalho\.lesshst  HFA\lbicalho
# 3                              C:\Users\lbicalho\.viminfo  HFA\lbicalho
# 4                 C:\Users\lbicalho\analise_publico.ipynb  HFA\lbicalho
# ...                                                   ...           ...
# 343873  C:\Users\lbicalho\VirtualBox VMs\debian grafic...  HFA\lbicalho
# 343874  C:\Users\lbicalho\VirtualBox VMs\debian grafic...  HFA\lbicalho
# 343875  C:\Users\lbicalho\VirtualBox VMs\debian grafic...  HFA\lbicalho
# 343876  C:\Users\lbicalho\VirtualBox VMs\debian grafic...  HFA\lbicalho
# 343877  C:\Users\lbicalho\VirtualBox VMs\debian grafic...  HFA\lbicalho
#
#        tamanho_legivel   bytes    extensao
# 0              25.00 B      25    .condarc
# ...

# %%
df.sort_values(by=['bytes'])
# Out:
#                                                   caminho  \
# 136164  C:\Users\lbicalho\Anaconda3\pkgs\googleapis-co...
# 221428  C:\Users\lbicalho\go\pkg\mod\cache\download\gi...
# 23562   C:\Users\lbicalho\Anaconda3\Lib\site-packages\...
# 7718    C:\Users\lbicalho\.vscode\extensions\ms-python...
# 147920  C:\Users\lbicalho\Anaconda3\pkgs\networkx-2.7....
# ...                                                   ...
# 221199     C:\Users\lbicalho\Downloads\cursoRedes\a05.mp4
# 221127  C:\Users\lbicalho\Downloads\Anaconda3-2022.05-...
# 220919  C:\Users\lbicalho\Documents\machinelearning\Pa...
# 343864  C:\Users\lbicalho\VirtualBox VMs\debian\debian...
# 343872  C:\Users\lbicalho\VirtualBox VMs\debian grafic...
#
#                            dono tamanho_legivel       bytes extensao
# 136164             HFA\lbicalho            0.00           0      .py
# 221428             HFA\lbicalho            0.00           0    .lock
# ...

# %%
df[df['dono'] == 'BUILTIN\\Administradores']
# Out:
#                                                   caminho  \
# 285     C:\Users\lbicalho\.VirtualBox\vbox-ssl-cacerti...
# 220787             C:\Users\lbicalho\Desktop\WinMerge.lnk
# 220812  C:\Users\lbicalho\Desktop\DESLIGAMENTOS\falha.txt
# 220814  C:\Users\lbicalho\Desktop\DESLIGAMENTOS\naoRes...
# 220815  C:\Users\lbicalho\Desktop\DESLIGAMENTOS\restam...
# ...                                                   ...
# 270579       C:\Users\lbicalho\stuff\impala\cmd\impala.go
# 270580  C:\Users\lbicalho\stuff\impala\imgprcss\functi...
# 270581  C:\Users\lbicalho\stuff\impala\imgprcss\privat...
# 270582  C:\Users\lbicalho\stuff\impala\imgprcss\public...
# 343864  C:\Users\lbicalho\VirtualBox VMs\debian\debian...
#
#                            dono tamanho_legivel       bytes extensao
# 285     BUILTIN\Administradores        90.00 kB       92156     .crt
# 220787  BUILTIN\Administradores        858.00 B         858     .lnk
# ...
